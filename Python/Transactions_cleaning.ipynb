# %% [markdown]
# # Transactions - Data Cleaning with Python

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd

# %% [markdown]
# ## Loading the Dataset

# %%
df = pd.read_csv("Intern_dataset(in) son.csv")

# %%
df
# Out:
#              Id  OrgId  TransactionTypeId Transaction_Date  OperationStatusId  \
# 0        531993    132                  1   4/18/2023 8:10                 20
# 1        532002    132                  1   4/18/2023 8:13                 20
# 2        532007    132                  1   4/18/2023 8:18                 20
# 3        532012    132                  1   4/18/2023 8:19                 20
# 4        532013     21                  1   4/18/2023 8:19                 20
# ...         ...    ...                ...              ...                ...
# 999995  7564988     49                  2  8/16/2024 10:01                 10
# 999996  7565005     49                  2  8/16/2024 10:02                 10
# 999997  7565011     79                  1  8/16/2024 10:02                 10
# 999998  7565055    104                  1  8/16/2024 10:03                 10
# 999999  7565057     49                  2  8/16/2024 10:03                 10
#
#                          CardlNumber  PersonId  Unnamed: 7
# 0                                NaN    101093         NaN
# 1                                NaN    101093         NaN
# 2                                NaN    101093         NaN
# 3                                NaN    101093         NaN
# 4                                NaN   1749567         NaN
# ...                              ...       ...         ...
# 999995  1FD1A6C0CC6FF437000000471736   1226287         NaN
# 999996  1FD1A6C0CC6FF4370000004CABE6   1971593         NaN
# 999997  1FD1A6C0CC6FF43700000034E4EF   1523555         NaN
# 999998  1FD1A6C0CC6FF4370000004D15D0    851270         NaN
# 999999  1FD1A6C0CC6FF437000000453BC8      3478         NaN
#
# [1000000 rows x 8 columns]

# %% [markdown]
# ## Removing unnecessary columns

# %%
df = df.drop(columns=['Unnamed: 7'])

# %% [markdown]
# ## Checking the data types

# %%
df.dtypes
# Out:
# Id                    int64
# OrgId                 int64
# TransactionTypeId     int64
# Transaction_Date     object
# OperationStatusId     int64
# CardlNumber          object
# PersonId              int64
# dtype: object

# %% [markdown]
# ## Checking for Duplicate Records

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Id, OrgId, TransactionTypeId, Transaction_Date, OperationStatusId, CardlNumber, PersonId]
# Index: []

# %% [markdown]
# ## Exporting the Cleaned Dataset

# %%
df.to_csv("transactions_cleaned.csv", index=False, encoding="utf-8-sig")
